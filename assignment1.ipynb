# %%
import pandas as pd
import numpy as np

# %%
#df1[123:201]

# %%
df1.shape
df1.head()
df1.columns=['Postcode','Borough','Neighbourhood']
df1.head()
df2=df1.drop(range(123,201))
df_gb = df2.groupby(['Postcode'])
for index, data in df_gb:
    print(index)
    print(data)

# %%
df2.groupby(['Postcode'])['Neighbourhood'].agg(','.join)
# Out:
# Postcode
# M1B                                        Malvern,Rouge
# M1C                 Highland Creek,Port Union,Rouge Hill
# M1E                      Guildwood,Morningside,West Hill
# M1G                                               Woburn
# M1H                                            Cedarbrae
# M1J                                  Scarborough Village
# M1K            East Birchmount Park,Ionview,Kennedy Park
# M1L                        Clairlea,Golden Mile,Oakridge
# M1M        Cliffcrest,Cliffside,Scarborough Village West
# M1N                           Birch Cliff,Cliffside West
# M1P    Dorset Park,Scarborough Town Centre,Wexford He...
# M1R                                     Maryvale,Wexford
# M1S                                            Agincourt
# M1T                Clarks Corners,Sullivan,Tam O'Shanter
# M1V    Agincourt North,L'Amoreaux East,Milliken,Steel...
# M1W                         L'Amoreaux West,Steeles West
# ...

# %%
df2.groupby(['Postcode','Borough'])['Neighbourhood'].agg(','.join).to_frame(name=None)
# Out:
#                                                                Neighbourhood
# Postcode Borough
# M1B      Scarborough                                           Malvern,Rouge
# M1C      Scarborough                    Highland Creek,Port Union,Rouge Hill
# M1E      Scarborough                         Guildwood,Morningside,West Hill
# M1G      Scarborough                                                  Woburn
# M1H      Scarborough                                               Cedarbrae
# M1J      Scarborough                                     Scarborough Village
# M1K      Scarborough               East Birchmount Park,Ionview,Kennedy Park
# M1L      Scarborough                           Clairlea,Golden Mile,Oakridge
# M1M      Scarborough           Cliffcrest,Cliffside,Scarborough Village West
# M1N      Scarborough                              Birch Cliff,Cliffside West
# M1P      Scarborough       Dorset Park,Scarborough Town Centre,Wexford He...
# ...

# %%
df2.groupby(['Postcode','Borough'])['Neighbourhood'].agg(','.join).to_frame(name=None)
# Out:
#                                                                Neighbourhood
# Postcode Borough
# M1B      Scarborough                                           Malvern,Rouge
# M1C      Scarborough                    Highland Creek,Port Union,Rouge Hill
# M1E      Scarborough                         Guildwood,Morningside,West Hill
# M1G      Scarborough                                                  Woburn
# M1H      Scarborough                                               Cedarbrae
# M1J      Scarborough                                     Scarborough Village
# M1K      Scarborough               East Birchmount Park,Ionview,Kennedy Park
# M1L      Scarborough                           Clairlea,Golden Mile,Oakridge
# M1M      Scarborough           Cliffcrest,Cliffside,Scarborough Village West
# M1N      Scarborough                              Birch Cliff,Cliffside West
# M1P      Scarborough       Dorset Park,Scarborough Town Centre,Wexford He...
# ...

# %%
df2.groupby(['Postcode'])['Neighbourhood'].agg(','.join)
# Out:
# Postcode
# M1B                                        Malvern,Rouge
# M1C                 Highland Creek,Port Union,Rouge Hill
# M1E                      Guildwood,Morningside,West Hill
# M1G                                               Woburn
# M1H                                            Cedarbrae
# M1J                                  Scarborough Village
# M1K            East Birchmount Park,Ionview,Kennedy Park
# M1L                        Clairlea,Golden Mile,Oakridge
# M1M        Cliffcrest,Cliffside,Scarborough Village West
# M1N                           Birch Cliff,Cliffside West
# M1P    Dorset Park,Scarborough Town Centre,Wexford He...
# M1R                                     Maryvale,Wexford
# M1S                                            Agincourt
# M1T                Clarks Corners,Sullivan,Tam O'Shanter
# M1V    Agincourt North,L'Amoreaux East,Milliken,Steel...
# M1W                         L'Amoreaux West,Steeles West
# ...

# %%
#df2

# %%
df_gb = df2.groupby(['Postcode'])

# %%
df2.groupby(['Postcode'])['Neighbourhood'].apply(lambda x: "{%s}" % ', '.join(x))
# Out:
# Postcode
# M1B                                     {Malvern, Rouge}
# M1C             {Highland Creek, Port Union, Rouge Hill}
# M1E                  {Guildwood, Morningside, West Hill}
# M1G                                             {Woburn}
# M1H                                          {Cedarbrae}
# M1J                                {Scarborough Village}
# M1K        {East Birchmount Park, Ionview, Kennedy Park}
# M1L                    {Clairlea, Golden Mile, Oakridge}
# M1M    {Cliffcrest, Cliffside, Scarborough Village West}
# M1N                        {Birch Cliff, Cliffside West}
# M1P    {Dorset Park, Scarborough Town Centre, Wexford...
# M1R                                  {Maryvale, Wexford}
# M1S                                          {Agincourt}
# M1T            {Clarks Corners, Sullivan, Tam O'Shanter}
# M1V    {Agincourt North, L'Amoreaux East, Milliken, S...
# M1W                      {L'Amoreaux West, Steeles West}
# ...

# %%
for index, data in df_gb:
    print(index)
    print(data)
# Out:
# M1B
#     Postcode      Borough Neighbourhood
# 101      M1B  Scarborough       Malvern
# 221      M1B  Scarborough         Rouge
# M1C
#     Postcode      Borough   Neighbourhood
# 69       M1C  Scarborough  Highland Creek
# 210      M1C  Scarborough      Port Union
# 222      M1C  Scarborough      Rouge Hill
# M1E
#     Postcode      Borough Neighbourhood
# 62       M1E  Scarborough     Guildwood
# 113      M1E  Scarborough   Morningside
# 273      M1E  Scarborough     West Hill
# M1G
#     Postcode      Borough Neighbourhood
# 282      M1G  Scarborough        Woburn
# M1H
#    Postcode      Borough Neighbourhood
# 18      M1H  Scarborough     Cedarbrae
# M1J
#     Postcode      Borough        Neighbourhood
# 229      M1J  Scarborough  Scarborough Village
# M1K
#    Postcode      Borough         Neighbourhood
# 47      M1K  Scarborough  East Birchmount Park
# 78      M1K  Scarborough               Ionview
# 84      M1K  Scarborough          Kennedy Park
# M1L
# ...
